# %%
import pandas as pd

uri = "..."
data = pd.read_csv(uri)

# %%
data.head()
# Out:
#    home  how_it_works  contact  bought
# 0     1             1        0       0
# 1     1             1        0       0
# 2     1             1        0       0
# 3     1             1        0       0
# 4     1             1        0       0

# %%
mapa = {
    "home": "principal",
    "how_it_works": "como_funciona",
    "contact" : "contato",
    "bought": "comprou" 
}

data = data.rename(columns = mapa)
data.head()
# Out:
#    principal  como_funciona  contato  comprou
# 0          1              1        0        0
# 1          1              1        0        0
# 2          1              1        0        0
# 3          1              1        0        0
# 4          1              1        0        0

# %%
x = data[["principal", "como_funciona", "contato"]]
y = data["comprou"]

x.shape
# Out:
# (99, 3)

# %%
teste_x = x[:75]
teste_y = y[:75]

treino_x = x[75:]
treino_y = y[75:]

print("Treinaremos com {} e testaremos com {}".format(len(treino_x), len(teste_x)))
# Out:
# Treinaremos com 24 e testaremos com 75

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

model = LinearSVC()
model.fit(treino_x, treino_y)
previsoes = model.predict(teste_x)

taxa_de_acerto = accuracy_score(teste_y, previsoes) * 100
print("A taxa de acerto foi {:.2f}".format(taxa_de_acerto))
# Out:
# A taxa de acerto foi 97.33

# %% [markdown]
# <h1><b>Utilizando a biblioteca para separar os dados</b></h1>

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

model = LinearSVC()
SEED = 20

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, random_state = SEED, test_size = 0.25, stratify = y)

model.fit(treino_x, treino_y)
previsoes = model.predict(teste_x)

acuracia = accuracy_score(teste_y, previsoes) * 100
print("A Acúracia foi de {:.2f}%".format(acuracia))
# Out:
# A Acúracia foi de 96.00%

# %%
teste_y.value_counts()
# Out:
# 0    17
# 1     8
# Name: comprou, dtype: int64

# %%
treino_y.value_counts()
# Out:
# 0    49
# 1    25
# Name: comprou, dtype: int64
